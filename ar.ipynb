# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA

commodities = ['Maize', 'Wheat', 'Oats', 'Soybeans']
DATA_PATH = '/kaggle/input/processed-data' # Remove the /kaggle/input prefix for reproducing the results
Y_COLUMN = 'Sep'

# %%
commodities_datasets = []
for commodity in commodities:
    dataset = pd.read_csv(f'{DATA_PATH}/full_{commodity}.csv')
    dataset['Date'] = pd.to_datetime(dataset['Date'])
    dataset = dataset[['Date', Y_COLUMN, "Prime"]]
    commodities_datasets.append(dataset)

# %%
train_datasets = []
test_datasets = []
for i in range(len(commodities_datasets)):
    split_index = int(len(commodities_datasets[i]) * 0.8)
    train_df = commodities_datasets[i].iloc[:split_index]
    test_df = commodities_datasets[i].iloc[split_index:]
    train_datasets.append(train_df)
    test_datasets.append(test_df)
    assert len(commodities_datasets[i]) == len(train_df) + len(test_df)

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Load your dataset (assuming it's in a pandas DataFrame 'df' with a 'value' column)
df = train_datasets[0]
data = df[Y_COLUMN]

# %%
def fit_ar_model(data, max_p):
    best_aic = float('inf')
    best_order = None
    best_model = None
    
    for p in range(1, max_p+1):
        model = ARIMA(data, order=(p, 0, 0))
        results = model.fit()

        print(f'Model AR({p}) - AIC: {results.aic}')

        # Choose the model with the lowest AIC
        if results.aic < best_aic:
            best_aic = results.aic
            best_order = p
            best_model = results

    print(f'\nBest model: AR({best_order}) - AIC: {best_aic}')
    return best_order, best_model

# %%
p_orders = []
for train_dataset in train_datasets:
    data = train_dataset[Y_COLUMN]
    best_order, best_model = fit_ar_model(data, max_p=15)  # You can adjust max_q as needed
    print(best_model.summary())

    residuals = best_model.resid
    plt.figure(figsize=(10, 4))
    plt.plot(residuals)
    plt.title('Residuals of the Best AR Model')
    plt.show()
    
    p_orders.append(best_order)
# Out:
# Model AR(1) - AIC: 8186.84167730022
# Model AR(2) - AIC: 8186.353273507424
# Model AR(3) - AIC: 8188.249103999102
# Model AR(4) - AIC: 8188.831838975693
# Model AR(5) - AIC: 8186.8782248545485
# Model AR(6) - AIC: 8188.770709417811
# Model AR(7) - AIC: 8189.378975854014
# Model AR(8) - AIC: 8190.025170461923
# Model AR(9) - AIC: 8191.420364234786
# Model AR(10) - AIC: 8193.009016007354
# Model AR(11) - AIC: 8194.829964811723
# Model AR(12) - AIC: 8195.47934611735
# Model AR(13) - AIC: 8190.2695441149635
# Model AR(14) - AIC: 8191.972693142261
# Model AR(15) - AIC: 8190.780609510661
#
# Best model: AR(2) - AIC: 8186.353273507424
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    Sep   No. Observations:                 1311
# Model:                 ARIMA(2, 0, 0)   Log Likelihood               -4089.177
# Date:                Sun, 20 Oct 2024   AIC                           8186.353
# Time:                        20:06:36   BIC                           8207.067
# Sample:                             0   HQIC                          8194.122
#                                - 1311
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        466.7775     97.780      4.774      0.000     275.132     658.423
# ar.L1          1.0423      0.021     49.800      0.000       1.001       1.083
# ar.L2         -0.0440      0.021     -2.120      0.034      -0.085      -0.003
# sigma2        29.8442      0.429     69.506      0.000      29.003      30.686
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             14815.78
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.23   Skew:                            -1.65
# Prob(H) (two-sided):                  0.00   Kurtosis:                        19.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Model AR(1) - AIC: 9697.270189093904
# Model AR(2) - AIC: 9697.932896071121
# Model AR(3) - AIC: 9694.718283106244
# Model AR(4) - AIC: 9696.409296365782
# Model AR(5) - AIC: 9696.46329941336
# Model AR(6) - AIC: 9696.00770621958
# Model AR(7) - AIC: 9697.633558810401
# Model AR(8) - AIC: 9695.712610603807
# Model AR(9) - AIC: 9691.557430881414
# Model AR(10) - AIC: 9693.374746744243
# Model AR(11) - AIC: 9692.274777405473
# Model AR(12) - AIC: 9692.179610038718
# Model AR(13) - AIC: 9692.831914878996
# Model AR(14) - AIC: 9694.41065345376
# Model AR(15) - AIC: 9695.965029136594
#
# Best model: AR(9) - AIC: 9691.557430881414
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    Sep   No. Observations:                 1273
# Model:                 ARIMA(9, 0, 0)   Log Likelihood               -4834.779
# Date:                Sun, 20 Oct 2024   AIC                           9691.557
# Time:                        20:07:04   BIC                           9748.198
# Sample:                             0   HQIC                          9712.831
#                                - 1273
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        648.0320     93.655      6.919      0.000     464.471     831.593
# ar.L1          0.9568      0.018     52.590      0.000       0.921       0.992
# ar.L2         -0.0294      0.026     -1.146      0.252      -0.080       0.021
# ar.L3          0.0543      0.025      2.170      0.030       0.005       0.103
# ar.L4         -0.0177      0.027     -0.652      0.514      -0.071       0.036
# ar.L5          0.0819      0.026      3.150      0.002       0.031       0.133
# ar.L6         -0.0250      0.027     -0.930      0.353      -0.078       0.028
# ar.L7          0.0340      0.028      1.217      0.224      -0.021       0.089
# ar.L8          0.0112      0.027      0.416      0.678      -0.042       0.064
# ar.L9         -0.0694      0.020     -3.396      0.001      -0.109      -0.029
# sigma2       116.0439      2.538     45.726      0.000     111.070     121.018
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1403.25
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.09   Skew:                             0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Model AR(1) - AIC: 8587.85713823468
# Model AR(2) - AIC: 8565.257147288714
# Model AR(3) - AIC: 8555.787966574371
# Model AR(4) - AIC: 8553.37669078038
# Model AR(5) - AIC: 8543.38288156332
# Model AR(6) - AIC: 8543.599970583415
# Model AR(7) - AIC: 8535.643051423162
# Model AR(8) - AIC: 8532.371337056018
# Model AR(9) - AIC: 8531.676988346768
# Model AR(10) - AIC: 8533.606190311322
# Model AR(11) - AIC: 8534.378496598592
# Model AR(12) - AIC: 8536.310854931846
# Model AR(13) - AIC: 8533.377264379898
# Model AR(14) - AIC: 8533.180272796679
# Model AR(15) - AIC: 8535.062007192086
#
# Best model: AR(9) - AIC: 8531.676988346768
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    Sep   No. Observations:                 1312
# Model:                 ARIMA(9, 0, 0)   Log Likelihood               -4254.838
# Date:                Sun, 20 Oct 2024   AIC                           8531.677
# Time:                        20:07:43   BIC                           8588.649
# Sample:                             0   HQIC                          8553.043
#                                - 1312
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        341.8985     67.234      5.085      0.000     210.122     473.675
# ar.L1          1.1271      0.017     65.682      0.000       1.093       1.161
# ar.L2         -0.2172      0.028     -7.728      0.000      -0.272      -0.162
# ar.L3          0.0549      0.026      2.102      0.036       0.004       0.106
# ar.L4         -0.0532      0.028     -1.886      0.059      -0.109       0.002
# ar.L5          0.1172      0.031      3.734      0.000       0.056       0.179
# ar.L6          0.0506      0.032      1.584      0.113      -0.012       0.113
# ar.L7         -0.0248      0.031     -0.806      0.420      -0.085       0.035
# ar.L8         -0.0121      0.027     -0.450      0.652      -0.065       0.041
# ar.L9         -0.0453      0.019     -2.431      0.015      -0.082      -0.009
# sigma2        38.2418      0.791     48.349      0.000      36.692      39.792
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2421.67
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.72   Skew:                            -0.47
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Model AR(1) - AIC: 10236.079346752042
# Model AR(2) - AIC: 10237.896532576397
# Model AR(3) - AIC: 10239.947069455204
# Model AR(4) - AIC: 10217.915696308199
# Model AR(5) - AIC: 10211.80863398423
# Model AR(6) - AIC: 10213.746919473411
# Model AR(7) - AIC: 10214.379779877167
# Model AR(8) - AIC: 10214.191624141768
# Model AR(9) - AIC: 10216.15421975077
# Model AR(10) - AIC: 10218.017419276373
# Model AR(11) - AIC: 10218.038807049994
# Model AR(12) - AIC: 10217.877596476033
# Model AR(13) - AIC: 10215.763479541289
# Model AR(14) - AIC: 10214.860149342563
# Model AR(15) - AIC: 10216.81887453527
#
# Best model: AR(5) - AIC: 10211.80863398423
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    Sep   No. Observations:                 1312
# Model:                 ARIMA(5, 0, 0)   Log Likelihood               -5098.904
# Date:                Sun, 20 Oct 2024   AIC                          10211.809
# Time:                        20:08:13   BIC                          10248.064
# Sample:                             0   HQIC                         10225.405
#                                - 1312
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1098.1792    278.863      3.938      0.000     551.618    1644.740
# ar.L1          0.9987      0.020     50.079      0.000       0.960       1.038
# ar.L2         -0.0048      0.035     -0.137      0.891      -0.073       0.064
# ar.L3         -0.1292      0.032     -3.981      0.000      -0.193      -0.066
# ar.L4          0.0555      0.033      1.671      0.095      -0.010       0.121
# ar.L5          0.0785      0.025      3.171      0.002       0.030       0.127
# sigma2       138.4319      2.181     63.483      0.000     134.158     142.706
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             12938.03
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.24   Skew:                            -1.65
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # Forecasting with the best AR(p) models

# %%
all_rmse_train = []  
all_rmse_test = [] 

for i, dataset in enumerate(commodities_datasets):
    best_ar_model = ARIMA(dataset[Y_COLUMN], order=(p_orders[i], 0, 0))
    best_ar_model_fit = best_ar_model.fit()

    start = 1  # Start from the second observation
    end = len(dataset[Y_COLUMN]) - 1  # End index for predictions

    best_ar_model_fit_predictions = best_ar_model_fit.predict(start=start, end=end)

    # Slice the actual data to exclude the first observation
    actual_data_without_first = dataset[Y_COLUMN][1:]

    plt.figure(figsize=(20, 15))
    plt.plot(actual_data_without_first, label='Actual Data', color='blue')

    plt.plot(best_ar_model_fit_predictions, label=f'AR({p_orders[i]}) Predictions', color='orange')

    plt.xlabel('Day')
    plt.ylabel('Contract Price')
    plt.title(f'Actual vs AR({p_orders[i]}) Predicted Values (Excluding First Observation), commodity = {commodities[i]}')
    plt.legend()
    plt.xlim(0,)
    plt.show()
    print("--------------------")
    
    training_rmse = (((best_ar_model_fit_predictions[:-len(test_datasets[i])] - actual_data_without_first[:-len(test_datasets[i])]) ** 2).mean())**0.5
    test_rmse = (((best_ar_model_fit_predictions[-len(test_datasets[i]):] - actual_data_without_first[-len(test_datasets[i]):]) ** 2).mean())**0.5
    all_rmse_train.append(training_rmse)
    all_rmse_test.append(test_rmse)
# Out:
# --------------------
# --------------------
# --------------------
# --------------------

# %%
n_commodities = len(commodities)
ind = np.arange(n_commodities)  # the x locations for the commodities
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
train_bars = ax.bar(ind - width/2, all_rmse_train, width, label='Train RMSE loss')
test_bars = ax.bar(ind + width/2, all_rmse_test, width, label='Test RMSE loss')

ax.set_xlabel('Commodities')
ax.set_ylabel('RMSE')
ax.set_title('Comparison of RMSE loss across commodities, AR models')
ax.set_xticks(ind)
ax.set_xticklabels(commodities)
ax.legend()

# Function to add labels above the bars
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(train_bars)
add_labels(test_bars)
plt.tight_layout()
plt.show()
